# %% [markdown]
# # Data Preprocessing

# %%
#!pip install numpy
#!pip install matplotlib
#!pip install pandas

# %%
#!pip list

# %%
#Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importing data

# %%
# Importing the datasets
df = pd.read_csv('alena.csv')

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95
#
# [400 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %% [markdown]
# В переменных нет пропущенных значений

# %%
# Importing the datasets
df1 = pd.read_csv('alena2.csv')

# %%
df1
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 495         1              0.87
# 496         1              0.96
# 497         1              0.93
# 498         0              0.73
# 499         0              0.84
#
# [500 rows x 9 columns]

# %% [markdown]
# # Visualization

# %%
# TOEFL Score distribution
df['TOEFL Score'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['SOP'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Можем сделать вывод, что в данном показателе существуют ошибки или выбросы

# %%
df['GRE Score'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Feature distribution
df['University Rating'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Statistics

# %%
# Dataset Statistics
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# 25%      3.000000    8.170000    0.000000          0.640000
# 50%      3.500000    8.610000    1.000000          0.730000
# 75%      4.000000    9.062500    1.000000          0.830000
# max      5.000000    9.920000    1.000000          0.970000

# %% [markdown]
# Видим что типичный обекст нашей выборки: студент с шансом поступления 0,72 в университет с рейтингом 3, и результатами по тестам: GRE-316, TOEFL-107, SOP-3,4,LOR-3,4,CGPA-8,6

# %% [markdown]
# # Mistakes

# %%
# Mistakes Deleting 
df = df.drop(df[df.CGPA > 9.8].index)
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  396.000000  396.000000   396.000000         396.000000  396.000000
# mean   200.159091  316.601010     4.673986           3.070707    3.388889
# std    115.787157   11.341306     0.055848           1.136306    1.005190
# min      1.000000  290.000000     4.521789           1.000000    1.000000
# 25%     99.750000  308.000000     4.634729           2.000000    2.500000
# 50%    199.500000  317.000000     4.672829           3.000000    3.500000
# 75%    300.250000  325.000000     4.711772           4.000000    4.000000
# max    400.000000  340.000000     4.787492           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  396.000000  396.000000  396.000000        396.000000
# mean     3.440657    2.147851    0.542929          0.721894
# std      0.894223    0.068545    0.498784          0.141204
# min      1.000000    1.941559    0.000000          0.340000
# 25%      3.000000    2.100163    0.000000          0.640000
# 50%      3.500000    2.150015    1.000000          0.730000
# 75%      4.000000    2.201936    1.000000          0.820000
# max      5.000000    2.282382    1.000000          0.970000

# %% [markdown]
# Видим что в выборке 4 не типичных показателя (по CGPA)

# %% [markdown]
# # Missing data

# %%
# Cheking Missing data
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.dtypes
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score          float64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
# Cheking Missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                    Total  Percent
# Serial No.             0      0.0
# GRE Score              0      0.0
# TOEFL Score            0      0.0
# University Rating      0      0.0
# SOP                    0      0.0
# LOR                    0      0.0
# CGPA                   0      0.0
# Research               0      0.0
# Chance of Admit        0      0.0

# %%
# Function Missing data (numeric)
def fill_missing_num(x):
    num_var = list(x._get_numeric_data().columns)
    for col_names in num_var:        
        prep_med = SimpleImputer(missing_values=np.nan, strategy='mean')
        prep_med.fit(x[num_var])
        x[num_var] = prep_med.transform(x[num_var])
    return(x)

# %%
# Function Missing data (non-numeric)
def fill_missing_char(x):
    char_var = list(set(x.columns) - set(x._get_numeric_data().columns))
    for col_names in char_var:        
        prep_fr = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        prep_fr.fit(x[char_var])
        x[char_var] = prep_fr.transform(x[char_var])
    return(x)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\user\anaconda3\envs\geralena\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from seaborn) (3.5.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from seaborn) (1.21.4)
# Requirement already satisfied: pandas>=0.23 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from matplotlib>=2.2->seaborn) (4.28.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: setuptools-scm>=4 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from matplotlib>=2.2->seaborn) (6.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (1.2.2)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (58.0.4)

# %%
# Re-Cheking Missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                    Total  Percent
# Serial No.             0      0.0
# GRE Score              0      0.0
# TOEFL Score            0      0.0
# University Rating      0      0.0
# SOP                    0      0.0
# LOR                    0      0.0
# CGPA                   0      0.0
# Research               0      0.0
# Chance of Admit        0      0.0

# %% [markdown]
# # Log

# %%
# Log Transformations for Skewed Distributions
df[['CGPA', 'TOEFL Score']] = np.log(df[['CGPA', 'TOEFL Score']])

import seaborn as sns
sns.set()
sns.pairplot(df)

# %% [markdown]
# Видим что щанс поступления больше всего зависит от GRE, TOEFL, CGPA

# %% [markdown]
# # Outliers

# %%
# Outliers
df = outliers(df)
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  396.000000  396.000000   396.000000         396.000000  396.000000
# mean   200.159091  316.601010     0.433012           3.070707    3.388889
# std    115.787157   11.341306     0.007758           1.136306    1.005190
# min      1.000000  290.000000     0.411386           1.000000    1.000000
# 25%     99.750000  308.000000     0.427603           2.000000    2.500000
# 50%    199.500000  317.000000     0.432928           3.000000    3.500000
# 75%    300.250000  325.000000     0.438296           4.000000    4.000000
# max    400.000000  340.000000     0.448529           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  396.000000  396.000000  396.000000        396.000000
# mean     3.440657   -0.270100    0.542929          0.721894
# std      0.894223    0.042242    0.498784          0.141204
# min      1.000000   -0.397005    0.000000          0.340000
# 25%      3.000000   -0.298386    0.000000          0.640000
# 50%      3.500000   -0.267260    1.000000          0.730000
# 75%      4.000000   -0.236562    1.000000          0.820000
# max      5.000000   -0.192105    1.000000          0.970000

# %%
# Function Outliers
def outliers(df):
    num_var = list(df._get_numeric_data().columns)
    for col_names in num_var:
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()-3*df[col_names].std() 
                            if y < df[col_names].mean()-3*df[col_names].std() else y)
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()+3*df[col_names].std() 
                            if y > df[col_names].mean()+3*df[col_names].std() else y)
    return(df)

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\user\anaconda3\envs\geralena\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from sklearn) (1.0.1)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from scikit-learn->sklearn) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from scikit-learn->sklearn) (3.0.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\user\anaconda3\envs\geralena\lib\site-packages (from scikit-learn->sklearn) (1.21.4)

# %%
from sklearn import preprocessing
dfm = df
dfm['Research'] = preprocessing.LabelEncoder().fit_transform(dfm['Research'])
dfm
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   \
# 0             1        337     0.446281                  4  4.5   4.5
# 1             2        324     0.432928                  4  4.0   4.5
# 2             3        316     0.428960                  3  3.0   3.5
# 3             4        322     0.436747                  3  3.5   2.5
# 4             5        314     0.427603                  2  2.0   3.0
# ..          ...        ...          ...                ...  ...   ...
# 395         396        324     0.436747                  3  3.5   3.5
# 396         397        325     0.432928                  3  3.0   3.5
# 397         398        330     0.443981                  4  5.0   4.5
# 398         399        312     0.427603                  3  3.5   4.0
# 399         400        333     0.445137                  4  5.0   4.0
#
#          CGPA  Research  Chance of Admit
# 0   -0.200357         1              0.92
# 1   -0.247755         1              0.76
# 2   -0.311839         1              0.72
# 3   -0.261303         1              0.80
# 4   -0.295065         0              0.65
# ..        ...       ...               ...
# 395 -0.236721         1              0.82
# 396 -0.232300         1              0.84
# 397 -0.211762         1              0.91
# 398 -0.253773         0              0.67
# 399 -0.199799         1              0.95
#
# [396 rows x 9 columns]

# %%
# Function Encoding
def encoding_char(x):
    char_var = list(set(x.columns) - set(x._get_numeric_data().columns))
    for col_names in char_var:
        f = pd.factorize(x[col_names])
        x[col_names] = pd.factorize(x[col_names])[0]
    return(x)

# %%
# Encoding categorical data
df = encoding_char(df)
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   \
# 0             1        337     0.446281                  4  4.5   4.5
# 1             2        324     0.432928                  4  4.0   4.5
# 2             3        316     0.428960                  3  3.0   3.5
# 3             4        322     0.436747                  3  3.5   2.5
# 4             5        314     0.427603                  2  2.0   3.0
# ..          ...        ...          ...                ...  ...   ...
# 395         396        324     0.436747                  3  3.5   3.5
# 396         397        325     0.432928                  3  3.0   3.5
# 397         398        330     0.443981                  4  5.0   4.5
# 398         399        312     0.427603                  3  3.5   4.0
# 399         400        333     0.445137                  4  5.0   4.0
#
#          CGPA  Research  Chance of Admit
# 0   -0.200357         1              0.92
# 1   -0.247755         1              0.76
# 2   -0.311839         1              0.72
# 3   -0.261303         1              0.80
# 4   -0.295065         0              0.65
# ..        ...       ...               ...
# 395 -0.236721         1              0.82
# 396 -0.232300         1              0.84
# 397 -0.211762         1              0.91
# 398 -0.253773         0              0.67
# 399 -0.199799         1              0.95
#
# [396 rows x 9 columns]

# %%
# Descriptive Statistics
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  396.000000  396.000000   396.000000         396.000000  396.000000
# mean   200.159091  316.601010     0.433012           3.070707    3.388889
# std    115.787157   11.341306     0.007758           1.136306    1.005190
# min      1.000000  290.000000     0.411386           1.000000    1.000000
# 25%     99.750000  308.000000     0.427603           2.000000    2.500000
# 50%    199.500000  317.000000     0.432928           3.000000    3.500000
# 75%    300.250000  325.000000     0.438296           4.000000    4.000000
# max    400.000000  340.000000     0.448529           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  396.000000  396.000000  396.000000        396.000000
# mean     3.440657   -0.270100    0.542929          0.721894
# std      0.894223    0.042242    0.498784          0.141204
# min      1.000000   -0.397005    0.000000          0.340000
# 25%      3.000000   -0.298386    0.000000          0.640000
# 50%      3.500000   -0.267260    1.000000          0.730000
# 75%      4.000000   -0.236562    1.000000          0.820000
# max      5.000000   -0.192105    1.000000          0.970000

# %% [markdown]
# # Correlations

# %%
# Cheking correlations
import seaborn as sns
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True)
plt.show()

# %% [markdown]
# # Exporting

# %%
dfr.to_csv('alena.csv', sep=',', index=False)
