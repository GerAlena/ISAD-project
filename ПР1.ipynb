# %% [markdown]
# # Data Preprocessing

# %%
#!pip install numpy
#!pip install matplotlib
#!pip install pandas

# %%
#!pip list

# %%
#Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importing data

# %%
# Importing the datasets
df = pd.read_csv('alena.csv')

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# Из исследуемой выборки следует удалить столбец с номером, так как он не нужен в исследованиях и не влияет на показатели в выборке

# %%
df = df.drop(columns=['Serial No.'])
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          400 non-null    int64
#  1   TOEFL Score        400 non-null    int64
#  2   University Rating  400 non-null    int64
#  3   SOP                400 non-null    float64
#  4   LOR                400 non-null    float64
#  5   CGPA               400 non-null    float64
#  6   Research           400 non-null    int64
#  7   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 25.1 KB

# %% [markdown]
# В переменных нет пропущенных значений

# %%
# Importing the datasets
df1 = pd.read_csv('alena2.csv')

# %%
df1
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
df['level CGPA']=np.where (df['CGPA']<=8.0,0,1)
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit   level CGPA
# 0                0.92           1
# ...

# %% [markdown]
# Для последующих исследований добавлю level CGPA, где 1 это высокий проходной балл, 0-низкий

# %% [markdown]
# # Visualization

# %%
# TOEFL Score distribution
df['TOEFL Score'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['SOP'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Можем сделать вывод, что в данном показателе существуют ошибки или выбросы

# %%
df['GRE Score'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Feature distribution
df['University Rating'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Statistics

# %%
# Dataset Statistics
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  396.000000   396.000000         396.000000  396.000000  396.000000
# mean   316.601010   107.290404           3.070707    3.388889    3.440657
# std     11.341306     5.980052           1.136306    1.005190    0.894223
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   111.250000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit   level CGPA
# count  396.000000  396.000000        396.000000  396.000000
# mean     8.585985    0.542929          0.721894    0.830808
# std      0.585143    0.498784          0.141204    0.375396
# min      6.800000    0.000000          0.340000    0.000000
# ...

# %% [markdown]
# Видим что типичный обекст нашей выборки: студент с шансом поступления 0,73 в университет с рейтингом 3, и результатами по тестам: GRE-317, TOEFL-107, SOP-3,5,LOR-3,5,CGPA-8,6

# %% [markdown]
# # Mistakes

# %%
# Mistakes Deleting 
df = df.drop(df[df.CGPA > 9.8].index)
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  396.000000   396.000000         396.000000  396.000000  396.000000
# mean   316.601010   107.290404           3.070707    3.388889    3.440657
# std     11.341306     5.980052           1.136306    1.005190    0.894223
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   111.250000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit   level CGPA
# count  396.000000  396.000000        396.000000  396.000000
# mean     8.585985    0.542929          0.721894    0.830808
# std      0.585143    0.498784          0.141204    0.375396
# min      6.800000    0.000000          0.340000    0.000000
# ...

# %% [markdown]
# Видим что в выборке 4 не типичных показателя (по CGPA)

# %% [markdown]
# # Missing data

# %%
# Cheking Missing data
df.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# level CGPA           0
# dtype: int64

# %%
df.dtypes
# Out:
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# level CGPA             int32
# dtype: object

# %%
# Cheking Missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                    Total  Percent
# GRE Score              0      0.0
# TOEFL Score            0      0.0
# University Rating      0      0.0
# SOP                    0      0.0
# LOR                    0      0.0
# CGPA                   0      0.0
# Research               0      0.0
# Chance of Admit        0      0.0
# level CGPA             0      0.0

# %%
# Function Missing data (numeric)
def fill_missing_num(x):
    num_var = list(x._get_numeric_data().columns)
    for col_names in num_var:        
        prep_med = SimpleImputer(missing_values=np.nan, strategy='mean')
        prep_med.fit(x[num_var])
        x[num_var] = prep_med.transform(x[num_var])
    return(x)

# %%
# Function Missing data (non-numeric)
def fill_missing_char(x):
    char_var = list(set(x.columns) - set(x._get_numeric_data().columns))
    for col_names in char_var:        
        prep_fr = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        prep_fr.fit(x[char_var])
        x[char_var] = prep_fr.transform(x[char_var])
    return(x)

# %%
#!pip install seaborn

# %%
# Re-Cheking Missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                    Total  Percent
# GRE Score              0      0.0
# TOEFL Score            0      0.0
# University Rating      0      0.0
# SOP                    0      0.0
# LOR                    0      0.0
# CGPA                   0      0.0
# Research               0      0.0
# Chance of Admit        0      0.0
# level CGPA             0      0.0

# %% [markdown]
# # Log

# %%
# Log Transformations for Skewed Distributions
df[['CGPA', 'TOEFL Score']] = np.log(df[['CGPA', 'TOEFL Score']])

import seaborn as sns
sns.set()
sns.pairplot(df)

# %% [markdown]
# Видим что щанс поступления больше всего зависит от GRE, TOEFL, CGPA

# %% [markdown]
# # Outliers

# %%
#!pip install sklearn

# %%
# Outliers
df = outliers(df)
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  396.000000   396.000000         396.000000  396.000000  396.000000
# mean   316.601010     4.673986           3.070707    3.388889    3.440657
# std     11.341306     0.055848           1.136306    1.005190    0.894223
# min    290.000000     4.521789           1.000000    1.000000    1.000000
# 25%    308.000000     4.634729           2.000000    2.500000    3.000000
# 50%    317.000000     4.672829           3.000000    3.500000    3.500000
# 75%    325.000000     4.711772           4.000000    4.000000    4.000000
# max    340.000000     4.787492           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit   level CGPA
# count  396.000000  396.000000        396.000000  396.000000
# mean     2.147851    0.542929          0.721894    0.830808
# std      0.068545    0.498784          0.141204    0.375396
# min      1.941559    0.000000          0.340000    0.000000
# ...

# %%
# Function Outliers
def outliers(df):
    num_var = list(df._get_numeric_data().columns)
    for col_names in num_var:
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()-3*df[col_names].std() 
                            if y < df[col_names].mean()-3*df[col_names].std() else y)
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()+3*df[col_names].std() 
                            if y > df[col_names].mean()+3*df[col_names].std() else y)
    return(df)

# %%
from sklearn import preprocessing
dfm = df
dfm['Research'] = preprocessing.LabelEncoder().fit_transform(dfm['Research'])
dfm
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR       CGPA  Research  \
# 0          337     4.770685                  4  4.5   4.5  2.266958         1
# 1          324     4.672829                  4  4.0   4.5  2.182675         1
# 2          316     4.644391                  3  3.0   3.5  2.079442         1
# 3          322     4.700480                  3  3.5   2.5  2.159869         1
# 4          314     4.634729                  2  2.0   3.0  2.105353         0
# ..         ...          ...                ...  ...   ...       ...       ...
# 395        324     4.700480                  3  3.5   3.5  2.201659         1
# 396        325     4.672829                  3  3.0   3.5  2.209373         1
# 397        330     4.753590                  4  5.0   4.5  2.246015         1
# 398        312     4.634729                  3  3.5   4.0  2.172476         0
# 399        333     4.762174                  4  5.0   4.0  2.267994         1
#
# ...

# %%
# Function Encoding
def encoding_char(x):
    char_var = list(set(x.columns) - set(x._get_numeric_data().columns))
    for col_names in char_var:
        f = pd.factorize(x[col_names])
        x[col_names] = pd.factorize(x[col_names])[0]
    return(x)

# %%
# Encoding categorical data
df = encoding_char(df)
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR       CGPA  Research  \
# 0          337     4.770685                  4  4.5   4.5  2.266958         1
# 1          324     4.672829                  4  4.0   4.5  2.182675         1
# 2          316     4.644391                  3  3.0   3.5  2.079442         1
# 3          322     4.700480                  3  3.5   2.5  2.159869         1
# 4          314     4.634729                  2  2.0   3.0  2.105353         0
# ..         ...          ...                ...  ...   ...       ...       ...
# 395        324     4.700480                  3  3.5   3.5  2.201659         1
# 396        325     4.672829                  3  3.0   3.5  2.209373         1
# 397        330     4.753590                  4  5.0   4.5  2.246015         1
# 398        312     4.634729                  3  3.5   4.0  2.172476         0
# 399        333     4.762174                  4  5.0   4.0  2.267994         1
#
# ...

# %%
# Descriptive Statistics
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  396.000000   396.000000         396.000000  396.000000  396.000000
# mean   316.601010     4.673986           3.070707    3.388889    3.440657
# std     11.341306     0.055848           1.136306    1.005190    0.894223
# min    290.000000     4.521789           1.000000    1.000000    1.000000
# 25%    308.000000     4.634729           2.000000    2.500000    3.000000
# 50%    317.000000     4.672829           3.000000    3.500000    3.500000
# 75%    325.000000     4.711772           4.000000    4.000000    4.000000
# max    340.000000     4.787492           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit   level CGPA
# count  396.000000  396.000000        396.000000  396.000000
# mean     2.147851    0.542929          0.721894    0.830808
# std      0.068545    0.498784          0.141204    0.375396
# min      1.941559    0.000000          0.340000    0.000000
# ...

# %% [markdown]
# # Correlations

# %%
# Cheking correlations
import seaborn as sns
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True)
plt.show()

# %% [markdown]
# # Exporting

# %%
df.to_csv('alena.csv', sep=',', index=False)
